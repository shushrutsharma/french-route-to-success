# %%
import numpy as np
import pandas as pd
import json as js
import flatten_json
import json_flatten

# %%
xGWC = pd.read_csv('xG WC 2018.csv', sep=',')

# %%
import matplotlib.pyplot as plt

# %%
xGWC = xGWC.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
import matplotlib.pyplot as plt
ax = xGWC[['For','xGF']].plot(kind='bar', title ="Goals Scored - xGF", figsize=(15, 10), legend=True, fontsize=12)
ax.set_xlabel("Teams", fontsize=12)
ax.set_ylabel("Goals - xG", fontsize=12)
plt.show()

# %%
xGWC.set_index('Team').plot.bar(rot=0, title='Goals - xGF', figsize=(25,20), fontsize=12)

# %%
New = xGWC.drop('Played', 1)

# %%
New = xGWC.drop('Against', 1)

# %%
New = xGWC.drop('xGA', 1)

# %%
New = xGWC.drop('GD', 1)

# %%
New = xGWC.drop('xGD', 1)

# %%
New = New.drop('GD', 1)

# %%
New = New.drop('xGA', 1)

# %%
New = New.drop('Against', 1)

# %%
New = New.drop('Played', 1)

# %%
New.set_index('Team').plot.bar(rot=0, title='Goals - xGF', figsize=(20,15), fontsize=12)

# %%
Def = xGWC.drop('Played', 1)
Def = Def.drop('For', 1)
Def = Def.drop('xGF', 1)
Def = Def.drop('GD', 1)
Def = Def.drop('xGD', 1)

# %%
Def.set_index('Team').plot.bar(rot=0, title='Conceded-xGA', figsize=(20,15), fontsize=12)

# %%
Go = xGWC.drop('Played', 1)
Go = Go.drop('For', 1)
Go = Go.drop('xGF', 1)
Go = Go.drop('Against', 1)
Go = Go.drop('xGA', 1)
